# %% [markdown]
# # The Marker Locations
#
# The marker location files are generated by KIM and contains the location of markers per frame of the KV image.

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd

# %%
marker_loc_df = pd.read_csv("X:\\2RESEARCH\\1_ClinicalData\\SPARK\\CMN\\Patient Measured Motion\\CMN_PAT01\\CMN_PAT01_Fx01\\MarkerLocationsGA_CouchShift_0.txt")

# %%
marker1_loc_df = pd.read_csv("X:\\2RESEARCH\\1_ClinicalData\\SPARK\\CMN\\Patient Measured Motion\\CMN_PAT01\\CMN_PAT01_Fx01\\MarkerLocationsGA_CouchShift_1.txt")

# %%
marker_loc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Frame No                167 non-null    int64
#  1    Time (sec)             167 non-null    float64
#  2    Gantry                 167 non-null    float64
#  3    Marker_0_AP            167 non-null    float64
#  4    Marker_0_LR            167 non-null    float64
#  5    Marker_0_SI            167 non-null    float64
#  6    Marker_1_AP            167 non-null    float64
#  7    Marker_1_LR            167 non-null    float64
#  8    Marker_1_SI            167 non-null    float64
#  9    Marker_2_AP            167 non-null    float64
#  10   Marker_2_LR            167 non-null    float64
#  11   Marker_2_SI            167 non-null    float64
#  12   Marker_0_X             167 non-null    int64
#  13   Marker_0_Y             167 non-null    int64
# ...

# %%
plt.scatter(x=marker_loc_df[" Time (sec)"], y=marker_loc_df[" Gantry"])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.scatter(x=marker1_loc_df[" Time (sec)"], y=marker1_loc_df[" Gantry"])

# %%
marker1_loc_df.columns = marker_loc_df.columns

# %%
plt.scatter(x=marker_loc_df[" Time (sec)"], y=marker_loc_df[" Marker_0_AP"])
plt.show()

# %%
plt.scatter(x=marker_loc_df[" Time (sec)"], y=marker_loc_df[" Marker_1_AP"])
plt.show()

# %%
plt.scatter(x=marker_loc_df[" Time (sec)"], y=marker_loc_df[" Marker_2_AP"])
plt.show()
